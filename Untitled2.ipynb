# %% [markdown]
# <a href="https://colab.research.google.com/github/mansiisharmaa/Ai-project/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import cv2
import numpy as np
from skimage import color
from skimage.feature import hog
import matplotlib.pyplot as plt

upload =files.upload()

image_path=list(upload.keys())[0]
image=cv2.imread(image_path)

if image is None:
  raise ValueError("Error in image Path")

image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_gray=color.rgb2gray(image_rgb)

features,hog_image=hog(image_gray,orientations=8,pixels_per_cell=(16,16),cells_per_block=(1,1),visualize=True)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(image_rgb,cmap="gray")

plt.subplot(1,2,2)
plt.title("HOG Features")
plt.imshow(hog_image,cmap="gray")

plt.show()
# Out:
#      <input type="file" id="files-82fe5b68-2f37-4b92-88ee-47aa96511318" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82fe5b68-2f37-4b92-88ee-47aa96511318">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

from google.colab import files
upload =files.upload()

image_path=list(upload.keys())[0]
image=cv2.imread(image_path)
image=cv2.resize(image,(640,480))

if image is None:
  raise ValueError("Error in image Path")

hog =cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
rects,weights=hog.detectMultiScale(image,winStride=(4,4),padding=(8,8),scale=1.05)

for(x,y,w,h) in rects:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)

cv2_imshow(image)
# Out:
#      <input type="file" id="files-9d0f9a94-22e8-4638-b6d1-315f8155bc35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d0f9a94-22e8-4638-b6d1-315f8155bc35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install ultralytics opencv-python numpy
import cv2
import numpy as np
import torch
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from google.colab import files
upload =files.upload()

image_path=list(upload.keys())[0]
image=cv2.imread(image_path)

model=YOLO("yolov8n.pt")
results=model(image)

for result in results:
  for box in result.boxes: # changed boxes to result.boxes
    x1,y1,x2,y2=map(int,box.xyxy[0])
    conf=box.conf[0].item()
    cls=int(box.cls[0].item())
    if cls==0 and conf>0.7:
      cv2.rectangle(image,(x1,y1),(x2,y2),(0,255,0),2)
      cv2.putText(image,f"Person:{conf:.2f}",(x1,y1-10),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),2)

cv2_imshow(image)
# Out:
# ...
#      <input type="file" id="files-9a4929b2-e532-4773-adba-f89f5c59dff5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a4929b2-e532-4773-adba-f89f5c59dff5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
